# %%
from lerobot.scripts import visualize_dataset
from dotenv import load_dotenv
import sys

from src.paths import REPO_ROOT, DATASETS_DIR, HF_NAME
load_dotenv(REPO_ROOT / ".env", override=True)
# Out:
# True

# %%
sys.argv = [
    "visualize_dataset.py",
    "--repo-id"      , "jonathm126/eval_so101_car_pick_and_place_96_episodes_v0_real_v0",        # repo name
    "--episode-index", f"{21}",                # episode to view
    "--root"         , '/home/jonathan/Github/IDC_Project-Sim_Real_Sim/eval/act/so101_car_pick_and_place/96_episodes_v0-real_v0_modified',   
    "--mode"         , "local",                         # or "distant"
    "--save"         , "0",                             # set to 1 if you want to export .rrd
]

# %%
visualize_dataset.main()
# Out:
#  80%|████████  | 16/20 [00:06<00:01,  2.78it/s][2026-01-31T08:44:19Z WARN  re_sdk_comms::server] Closing connection to client at 127.0.0.1:34932: The receiving end of the channel was closed
# [2026-01-31T08:44:20Z WARN  re_sdk_comms::server] Closing connection to client at 127.0.0.1:45798: The receiving end of the channel was closed
#  85%|████████▌ | 17/20 [00:07<00:01,  2.75it/s][2026-01-31T08:44:20Z WARN  re_sdk_comms::server] Closing connection to client at 127.0.0.1:45810: The receiving end of the channel was closed
#  90%|█████████ | 18/20 [00:07<00:00,  2.80it/s][2026-01-31T08:44:20Z WARN  re_sdk_comms::buffered_client] Failed to send message after 3 attempts: Failed to send to Rerun server at 127.0.0.1:9876: Connection reset by peer (os error 104)
# 100%|██████████| 20/20 [00:08<00:00,  2.45it/s]
# [2026-01-31T08:44:23Z WARN  re_sdk_comms::buffered_client] Dropping messages because tcp client has timed out.
# [2026-01-31T08:44:23Z WARN  re_sdk_comms::buffered_client] Dropping messages because tcp client has timed out.

# %%
# sys.argv = [
#     "visualize_dataset.py",
#     "--repo-id"      , f"{HF_NAME}/{REPO_NAME}",        # repo name
#     "--episode-index", f"{episode_idx}",                # episode to view
#     "--root"         , f"{DATASETS_DIR}/{REPO_NAME}",   # local path
#     "--mode"         , "local",                         # or "distant"
#     "--save"         , "5",                             # set to 1 if you want to export .rrd
# ]
